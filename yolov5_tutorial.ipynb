# %% [markdown]
# ### Followed this link:  https://docs.ultralytics.com/tutorials/nvidia-jetson/

# %%
#!git clone https://github.com/ultralytics/yolov5

# %%
cd yolov5
# Out:
# /home/aarohi/python_examples/Run_pytorch_on_jetson/3_yolov5_custommodeldetect/yolov5_on_jetson/yolov5

# %%
#sudo apt install -y libfreetype6-dev

#!pip3 install -r requirements.txt

# %% [markdown]
# We cannot install PyTorch and Torchvision from pip because they are not compatible to run on Jetson platform which is based on ARM aarch64 architecture. Therefore we need to manually install pre-built PyTorch pip wheel and compile/ install Torchvision from source.
#
# Visit this page to access all the PyTorch and Torchvision links. https://forums.developer.nvidia.com/t/pytorch-for-jetson/72048
#
# Pick the right version of Pytorch and torchvision as per your Jetpack version. My Jetpack is 4.6

# %%
#cd yolov5

#!wget https://github.com/ultralytics/yolov5/releases/download/v6.1/yolov5s.pt

# %%
# !python -c "import cv2; print(cv2.__version__)"
# Out:
# 4.5.1

# %%
# !python detect.py --source 3 --weights yolov5s.pt
# Out:
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# nvarguscamerasrc ! video/x-raw(memory:NVMM), width=(int)1280, height=(int)720, format=(string)NV12, framerate=(fraction)60/1 ! nvvidconv flip-method=0 ! video/x-raw, width=(int)1280, height=(int)720, format=(string)BGRx ! videoconvert ! video/x-raw, format=(string)BGR ! appsink
# detect: weights=['yolov5s.pt'], source=3, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# WARNING ⚠️ Python 3.7.0 is required by YOLOv5, but Python 3.6.9 is currently installed
# nvbuf_utils: Could not get EGL display connection
# ...

# %%
# !python detect.py --source 'rtsp://admin:hello123@192.168.29.126:554/cam/realmonitor?channel=1&subtype=0' --weights yolov5s.pt
# Out:
# detect: weights=['yolov5s.pt'], source=rtsp://admin:hello123@192.168.29.126:554/cam/realmonitor?channel=1&subtype=0, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# WARNING ⚠️ Python 3.7.0 is required by YOLOv5, but Python 3.6.9 is currently installed
# YOLOv5 🚀 v7.0-56-gc0ca1d2 Python-3.6.9 torch-1.8.0 CUDA:0 (NVIDIA Tegra X1, 3956MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# 1/1: rtsp://admin:hello123@192.168.29.126:554/cam/realmonitor?channel=1&subtype=0...  Success (inf frames 1920x1080 at 25.00 FPS)
#
# 0: 384x640 1 person, 2 tvs, 1 keyboard, 2850.4ms
# ...

# %%
# Working succesfully

# cv2.VideoCapture(0) tries to open the first Video For Linux compatible camera. They are usually USB cameras. Check available cameras with v4l2-ctl tool.


#!python detect.py --source 0 --weights yolov5s.pt
# !python detect.py --source 1 --weights yolov5s.pt  #source 1 is for webcam. <sometimes it work with source 0 and sometime with 1
# Out:
# detect: weights=['yolov5s.pt'], source=1, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# WARNING ⚠️ Python 3.7.0 is required by YOLOv5, but Python 3.6.9 is currently installed
# YOLOv5 🚀 v7.0-56-gc0ca1d2 Python-3.6.9 torch-1.8.0 CUDA:0 (NVIDIA Tegra X1, 3956MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# [ WARN:0] global /home/aarohi/opencv/modules/videoio/src/cap_gstreamer.cpp (961) open OpenCV | GStreamer warning: Cannot query video position: status=0, value=-1, duration=-1
# 1/1: 1...  Success (inf frames 2304x1536 at 2.00 FPS)
#
# 0: 448x640 1 tv, 3338.3ms
# ...

# %%
# !python detect.py --source ../cars.mp4 --weights yolov5s.pt
#with opencv 4.1.1 you wil get error. You need 4.5.1
# Out:
# detect: weights=['yolov5s.pt'], source=../cars.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# WARNING ⚠️ Python 3.7.0 is required by YOLOv5, but Python 3.6.9 is currently installed
# YOLOv5 🚀 v7.0-56-gc0ca1d2 Python-3.6.9 torch-1.8.0 CUDA:0 (NVIDIA Tegra X1, 3956MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# WARNING ⚠️ NMS time limit 0.550s exceeded
# video 1/1 (1/3000) /home/aarohi/python_examples/Run_pytorch_on_jetson/3_yolov5_custommodeldetect/yolov5_on_jetson/cars.mp4: 384x640 2 persons, 8 cars, 1 bus, 2 trucks, 229.6ms
# ...

# %%
# !python detect.py --source ../test_img.jpg --weights yolov5s.pt
# Out:
# detect: weights=['yolov5s.pt'], source=../test_img.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# WARNING ⚠️ Python 3.7.0 is required by YOLOv5, but Python 3.6.9 is currently installed
# YOLOv5 🚀 v7.0-56-gc0ca1d2 Python-3.6.9 torch-1.8.0 CUDA:0 (NVIDIA Tegra X1, 3964MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /home/aarohi/python_examples/Run_pytorch_on_jetson/3_yolov5_custommodeldetect/yolov5_on_jetson/test_img.jpg: 416x640 1 person, 121.1ms
# ...

# %%
# Working succesfully
# !python detect.py --source 0 --weights yolov5s.pt
# Out:
# detect: weights=['yolov5s.pt'], source=0, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# WARNING ⚠️ Python 3.7.0 is required by YOLOv5, but Python 3.6.9 is currently installed
# YOLOv5 🚀 v7.0-56-gc0ca1d2 Python-3.6.9 torch-1.8.0 CUDA:0 (NVIDIA Tegra X1, 3964MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# [ WARN:0] global /home/nvidia/host/build_opencv/nv_opencv/modules/videoio/src/cap_gstreamer.cpp (933) open OpenCV | GStreamer warning: Cannot query video position: status=0, value=-1, duration=-1
# 1/1: 0...  Success (inf frames 2304x1536 at 2.00 FPS)
#
# 0: 448x640 1 person, 2 mouses, 2568.8ms
# ...
